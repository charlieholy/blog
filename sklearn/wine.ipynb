# %%
from sklearn import tree
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
wine = load_wine()
wine.data.shape
wine.target
import pandas as pd
pd.concat([pd.DataFrame(wine.data),pd.DataFrame(wine.target)],axis=1)
wine.feature_names
wine.target_names
Xtrain, Xtest, Ytrain, Ytest = train_test_split(wine.data,wine.target,test_size=0.3)
Xtrain.shape
Xtest.shape
Ytrain
# Out:
# 0.8518518518518519

# %%
clf = tree.DecisionTreeClassifier(criterion="entropy"
                                  ,random_state=30
                                  ,splitter='random'
                                  ,max_depth=3
                                 # ,min_samples_leaf=10
                                 #,min_samples_split=10
                                 )
clf = clf.fit(Xtrain, Ytrain)
score = clf.score(Xtrain, Ytrain) #返回预测的准确度accuracy
score
# Out:
# 0.9274193548387096

# %%
score = clf.score(Xtest, Ytest) #返回预测的准确度accuracy
score
# Out:
# 0.8333333333333334

# %%
feature_name = ['酒精','苹果酸','灰','灰的碱性','镁','总酚','类黄酮','非黄烷类酚类','花青素','颜色强度','色调','od280/od315稀释葡萄酒','脯氨酸']

import graphviz
dot_data = tree.export_graphviz(clf
                                ,feature_names = feature_name
                                ,class_names=["琴酒","雪莉","贝尔摩德"]
                                ,filled=True
                                ,rounded=True
                               ) 
graph = graphviz.Source(dot_data)
graph

# %%
clf.feature_importances_
[*zip(feature_name,clf.feature_importances_)]
# Out:
# [('酒精', 0.0),
#  ('苹果酸', 0.0),
#  ('灰', 0.0),
#  ('灰的碱性', 0.1014767512954669),
#  ('镁', 0.0),
#  ('总酚', 0.0),
#  ('类黄酮', 0.12181165959026173),
#  ('非黄烷类酚类', 0.0),
#  ('花青素', 0.0),
#  ('颜色强度', 0.0),
#  ('色调', 0.03468552670118614),
#  ('od280/od315稀释葡萄酒', 0.2693026314802502),
#  ('脯氨酸', 0.4727234309328351)]

# %%
# %%cmd
# ls
# Out:
# UsageError: Cell magic `%%cmd` not found.
